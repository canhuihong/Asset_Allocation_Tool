# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 模拟生成一个简单的收益率序列
dates = pd.date_range('2025-01-01', periods=100)
data = np.random.randn(100).cumsum()
df = pd.DataFrame(data, index=dates, columns=['Portfolio_Value'])

# 画图
df.plot()
plt.show()
